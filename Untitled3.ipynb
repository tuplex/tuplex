# %%
path = '/Users/leonhards/Downloads/flights/flights_on_time_performance_2003_06.csv'


lines = open(path, 'r').readlines()

# %%
len(lines)
# Out:
# 536497

# %%
import random

# %%
# create small samples
n = 50
L = 50
idx = random.randint(n+1, len(lines) - n - L)
with open('/Users/leonhards/projects/tuplex-public/tuplex/test/resources/hyperspecialization/flights_2003_06.sample.csv', 'w') as fp:
    fp.writelines(lines[:n+1] + lines[idx:idx+L] + lines[-n:])

# %%
# Out:
# 429394

# %%
# !tail /Users/leonhards/Downloads/flights/flights_on_time_performance_2003_06.csv
# Out:
# 2003,2,6,9,1,2003-06-09,"OO",20304,"OO","N308SW","3685",14869,1486902,34614,"SLC","Salt Lake City, UT","UT","49","Utah",87,12280,1228001,32280,"IDA","Idaho Falls, ID","ID","16","Idaho",83,"1645","1645",0.00,0.00,0.00,0,"1600-1659",7.00,"1652","1735",3.00,"1750","1738",-12.00,0.00,0.00,-1,"1700-1759",0.00,"",0.00,65.00,53.00,43.00,1.00,188.00,1,,,,,,"",,,,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2003,2,6,9,1,2003-06-09,"OO",20304,"OO","N308SW","3685",12280,1228001,32280,"IDA","Idaho Falls, ID","ID","16","Idaho",83,14869,1486902,34614,"SLC","Salt Lake City, UT","UT","49","Utah",87,"1820","1815",0.00,0.00,0.00,0,"1800-1859",5.00,"1820","1857",5.00,"1921","1902",-19.00,0.00,0.00,-2,"1900-1959",0.00,"",0.00,61.00,42.00,32.00,1.00,188.00,1,,,,,,"",,,,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# ...
