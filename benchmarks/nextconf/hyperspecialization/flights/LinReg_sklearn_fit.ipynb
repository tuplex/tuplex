# %%
import pandas as pd

# %%
import sklearn

# %%
import numpy

# %%
import glob

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df = pd.DataFrame()
for path in glob.glob('preprocess/features.part0.csv'):
    try:
        print(path)
        df = pd.concat((df, pd.read_csv(path, nrows=100000 )))
    except:
        print('bad path: ' + path)
# Out:
# preprocess/features.part0.csv

# %%
import vaex

# %%
df = vaex.open('preprocess/features.part0.csv')

# %%
df.describe()
# Out:
#                     f_quarter            f_month     f_day_of_month  \
# data_type             float64            float64            float64
# count               202687653          202687653          202687653
# NA                          0                  0                  0
# mean       2.1820693439081857  5.672293827389673  13.62521150708672
# std                  1.344828            3.88757           9.775277
# min                       0.0                0.0                0.0
# max                       4.0               12.0               31.0
#
#                 f_day_of_week           f_carrier      f_origin_state  \
# data_type             float64             float64             float64
# count               202687653           202687653           202687653
# NA                          0                   0                   0
# mean       3.4211559300062544  15.813043126016167  23.572713346283603
# std                  2.290206           10.379335           15.545308
# ...

# %%
df.agg(['mean', 'std'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.agg(['mean', 'std'])
#
# File ~/.local/lib/python3.10/site-packages/vaex/dataframe.py:288, in DataFrame.__getattr__(self, name)
#     286     return self.__hidden__[name].__get__(self)
#     287 else:
# --> 288     return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrameLocal' object has no attribute 'agg'

# %%
df[~df['t_carrier_delay'].isna()].export('preprocess/cleaned_features.csv', index=None)

# %%
df = pd.read_csv('preprocess/cleaned_features.csv')

# %%
df.mean()
# Out:
# f_quarter                 0.000000
# f_month                   0.000000
# f_day_of_month            0.000000
# f_day_of_week             0.000000
# f_carrier                16.652574
# f_origin_state           23.290675
# f_dest_state             23.256459
# f_dep_delay               0.000000
# f_arr_delay               0.000000
# f_crs_arr_hour            0.000000
# f_crs_dep_hour            0.000000
# f_crs_arr_5min            0.000000
# f_crs_dep_5min            0.000000
# t_carrier_delay          17.397560
# t_weather_delay           3.028410
# t_nas_delay              15.210842
# t_security_delay          0.097576
# t_late_aircraft_delay    21.900108
# dtype: float64

# %%
 	f_quarter 	f_month 	f_day_of_month 	f_day_of_week 	f_carrier 	f_origin_state 	f_dest_state 	f_dep_delay 	f_arr_delay 	f_crs_arr_hour 	f_crs_dep_hour 	f_crs_arr_5min 	f_crs_dep_5min 	t_carrier_delay 	t_weather_delay 	t_nas_delay 	t_security_delay 	t_late_aircraft_delay
mean 	3.945840 	9.864600 	15.73506 	4.00214 	8.899110 	23.118550 	23.199180 	4.894120 	6.171920 	14.472720 	13.318760 	5.548890 	5.099070 	NaN 	NaN 	NaN 	NaN 	NaN
std 	0.462287 	1.155716 	9.05991 	1.97644 	8.940548 	14.538498 	14.612893 	17.695656 	19.410129 	5.216699 	4.975309 	3.515781 	3.568888 	NaN 	NaN 	NaN 	NaN 	NaN

# %%
len(df)
# Out:
# 100000

# %%
# normalize manually for now...

# %%
df.agg(['mean', 'std'])
# Out:
#       f_quarter   f_month  f_day_of_month  f_day_of_week  f_carrier  \
# mean   3.945840  9.864600        15.73506        4.00214   8.899110
# std    0.462287  1.155716         9.05991        1.97644   8.940548
#
#       f_origin_state  f_dest_state  f_dep_delay  f_arr_delay  f_crs_arr_hour  \
# mean       23.118550     23.199180     4.894120     6.171920       14.472720
# std        14.538498     14.612893    17.695656    19.410129        5.216699
#
#       f_crs_dep_hour  f_crs_arr_5min  f_crs_dep_5min  t_carrier_delay  \
# mean       13.318760        5.548890        5.099070              NaN
# std         4.975309        3.515781        3.568888              NaN
#
#       t_weather_delay  t_nas_delay  t_security_delay  t_late_aircraft_delay
# mean              NaN          NaN               NaN                    NaN
# std               NaN          NaN               NaN                    NaN

# %%
df[df.f_arr_delay > 0.]

# %%
df[df.f_arr_delay >= 0.]

# %%
# !pip3 install vaex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 7.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 KB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 KB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 25.3 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 KB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 9.6 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
feature_columns = ['f_quarter', 'f_month', 'f_day_of_month', 'f_day_of_week', 'f_carrier', 'f_origin_state', 'f_dest_state', 'f_dep_delay', 'f_arr_delay', 'f_crs_arr_hour', 'f_crs_dep_hour', 'f_crs_arr_5min', 'f_crs_dep_5min']

# %%
target_var = 't_nas_delay'

# %%
X = df[feature_columns].values

# %%
df.columns
