# %% [markdown]
# ## general-case code
#
# source: https://godbolt.org/z/cP81zsTnY
#
# this here is the code after applying -O3
#
# ```
# define dso_local i64 @process_cells(i8* nocapture readnone, i8** nocapture readonly, i64* nocapture readnone) local_unnamed_addr #3 !dbg !1359 {
#   call void @llvm.dbg.value(metadata i8* %0, metadata !1364, metadata !DIExpression()), !dbg !1384
#   call void @llvm.dbg.value(metadata i8** %1, metadata !1365, metadata !DIExpression()), !dbg !1384
#   call void @llvm.dbg.value(metadata i64* %2, metadata !1366, metadata !DIExpression()), !dbg !1384
#   %4 = getelementptr inbounds i8*, i8** %1, i64 3, !dbg !1385
#   %5 = load i8*, i8** %4, align 8, !dbg !1385, !tbaa !1356
#   call void @llvm.dbg.value(metadata i8* %5, metadata !1367, metadata !DIExpression()), !dbg !1384
#   %6 = getelementptr inbounds i8*, i8** %1, i64 2, !dbg !1386
#   %7 = load i8*, i8** %6, align 8, !dbg !1386, !tbaa !1356
#   call void @llvm.dbg.value(metadata i8* %7, metadata !1368, metadata !DIExpression()), !dbg !1384
#   %8 = getelementptr inbounds i8*, i8** %1, i64 57, !dbg !1387
#   %9 = load i8*, i8** %8, align 8, !dbg !1387, !tbaa !1356
#   call void @llvm.dbg.value(metadata i8* %9, metadata !1369, metadata !DIExpression()), !dbg !1384
#   %10 = getelementptr inbounds i8*, i8** %1, i64 20, !dbg !1388
#   %11 = load i8*, i8** %10, align 8, !dbg !1388, !tbaa !1356
#   call void @llvm.dbg.value(metadata i8* %11, metadata !1370, metadata !DIExpression()), !dbg !1384
#   %12 = tail call i32 @strcmp(i8* %11, i8* getelementptr inbounds ([6 x i8], [6 x i8]* @.str, i64 0, i64 0)) #13, !dbg !1389
#   %13 = icmp eq i32 %12, 0, !dbg !1390
#   br i1 %13, label %14, label %57, !dbg !1391
#
# 14:                                               ; preds = %3
#   %15 = load i8, i8* %9, align 1, !dbg !1392
#   %16 = icmp eq i8 %15, 0, !dbg !1394
#   br i1 %16, label %19, label %17, !dbg !1395
#
# 17:                                               ; preds = %14
#   call void @llvm.dbg.value(metadata i8* %9, metadata !583, metadata !DIExpression()) #12, !dbg !1396
#   %18 = tail call double @strtod(i8* nocapture nonnull %9, i8** null) #12, !dbg !1399
#   call void @llvm.dbg.value(metadata double %18, metadata !1371, metadata !DIExpression()), !dbg !1400
#   br label %19
#
# 19:                                               ; preds = %14, %17
#   %20 = phi double [ %18, %17 ], [ 0.000000e+00, %14 ], !dbg !1401
#   call void @llvm.dbg.value(metadata double %20, metadata !1371, metadata !DIExpression()), !dbg !1400
#   call void @llvm.dbg.value(metadata i8* %5, metadata !589, metadata !DIExpression()) #12, !dbg !1402
#   %21 = tail call i64 @strtol(i8* nocapture nonnull %5, i8** null, i32 10) #12, !dbg !1404
#   %22 = trunc i64 %21 to i32, !dbg !1404
#   call void @llvm.dbg.value(metadata i32 %22, metadata !1374, metadata !DIExpression()), !dbg !1400
#   call void @llvm.dbg.value(metadata i8* %7, metadata !589, metadata !DIExpression()) #12, !dbg !1405
#   %23 = tail call i64 @strtol(i8* nocapture nonnull %7, i8** null, i32 10) #12, !dbg !1407
#   %24 = trunc i64 %23 to i32, !dbg !1407
#   call void @llvm.dbg.value(metadata i32 %24, metadata !1375, metadata !DIExpression()), !dbg !1400
#   %25 = shl i32 %22, 4, !dbg !1408
#   %26 = add nsw i32 %25, %24, !dbg !1409
#   call void @llvm.dbg.value(metadata i32 %26, metadata !1376, metadata !DIExpression()), !dbg !1400
#   %27 = load %struct.AggregateEntry*, %struct.AggregateEntry** @_ZL7agg_map, align 8, !dbg !1410, !tbaa !1356
#   %28 = sext i32 %26 to i64, !dbg !1410
#   call void @llvm.dbg.value(metadata %struct.AggregateEntry* undef, metadata !1377, metadata !DIExpression()), !dbg !1400
#   %29 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 0, !dbg !1411
#   %30 = load i8, i8* %29, align 8, !dbg !1411, !tbaa !1346, !range !1413
#   %31 = icmp eq i8 %30, 0, !dbg !1411
#   br i1 %31, label %40, label %32, !dbg !1414
#
# 32:                                               ; preds = %19
#   %33 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 1, !dbg !1400
#   %34 = load i64, i64* %33, align 8, !dbg !1415, !tbaa !1416
#   %35 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 2, !dbg !1400
#   %36 = load double, double* %35, align 8, !dbg !1417, !tbaa !1418
#   %37 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 3, !dbg !1400
#   %38 = load double, double* %37, align 8, !dbg !1419, !tbaa !1420
#   %39 = add i64 %34, 1, !dbg !1414
#   br label %43, !dbg !1414
#
# 40:                                               ; preds = %19
#   store i8 1, i8* %29, align 8, !dbg !1421, !tbaa !1346
#   %41 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 1, !dbg !1423
#   %42 = bitcast i64* %41 to i8*, !dbg !1424
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 %42, i8 0, i64 24, i1 false), !dbg !1425
#   br label %43, !dbg !1424
#
# 43:                                               ; preds = %32, %40
#   %44 = phi double [ %38, %32 ], [ 0.000000e+00, %40 ], !dbg !1419
#   %45 = phi double [ %36, %32 ], [ 0.000000e+00, %40 ], !dbg !1417
#   %46 = phi i64 [ %39, %32 ], [ 1, %40 ]
#   %47 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 1, !dbg !1415
#   %48 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 2, !dbg !1417
#   call void @llvm.dbg.value(metadata double %45, metadata !1380, metadata !DIExpression()), !dbg !1400
#   %49 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %27, i64 %28, i32 3, !dbg !1419
#   call void @llvm.dbg.value(metadata double %44, metadata !1381, metadata !DIExpression()), !dbg !1400
#   call void @llvm.dbg.value(metadata i64 %46, metadata !1379, metadata !DIExpression()), !dbg !1400
#   %50 = fsub double %20, %45, !dbg !1426
#   call void @llvm.dbg.value(metadata double %50, metadata !1382, metadata !DIExpression()), !dbg !1400
#   %51 = sitofp i64 %46 to double, !dbg !1427
#   %52 = fdiv double %50, %51, !dbg !1428
#   %53 = fadd double %45, %52, !dbg !1429
#   call void @llvm.dbg.value(metadata double %53, metadata !1380, metadata !DIExpression()), !dbg !1400
#   %54 = fsub double %20, %53, !dbg !1430
#   call void @llvm.dbg.value(metadata double %54, metadata !1383, metadata !DIExpression()), !dbg !1400
#   %55 = fmul double %50, %54, !dbg !1431
#   %56 = fadd double %44, %55, !dbg !1432
#   call void @llvm.dbg.value(metadata double %56, metadata !1381, metadata !DIExpression()), !dbg !1400
#   store i64 %46, i64* %47, align 8, !dbg !1433, !tbaa !1416
#   store double %53, double* %48, align 8, !dbg !1434, !tbaa !1418
#   store double %56, double* %49, align 8, !dbg !1435, !tbaa !1420
#   br label %57, !dbg !1436
#
# 57:                                               ; preds = %43, %3
#   ret i64 0, !dbg !1437
# }
# ```

# %% [markdown]
# As x86 assembly:
#
# Note, Lambda is Haswell (check list form here: https://en.wikichip.org/wiki/intel/cpuid)
# I.e. family 6, model 63
#
# ```
# process_cells:                          # @process_cells
#         push    r15
#         push    r14
#         push    rbx
#         sub     rsp, 16
#         mov     r14, qword ptr [rsi + 16]
#         mov     r15, qword ptr [rsi + 24]
#         mov     rbx, qword ptr [rsi + 456]
#         mov     rdi, qword ptr [rsi + 160]
#         mov     esi, offset .L.str
#         call    strcmp
#         test    eax, eax
#         jne     .LBB1_8
#         cmp     byte ptr [rbx], 0
#         je      .LBB1_2
#         mov     rdi, rbx
#         xor     esi, esi
#         call    strtod
#         jmp     .LBB1_4
# .LBB1_2:
#         xorpd   xmm0, xmm0
# .LBB1_4:
#         movsd   qword ptr [rsp + 8], xmm0 # 8-byte Spill
#         mov     rdi, r15
#         xor     esi, esi
#         mov     edx, 10
#         call    strtol
#         mov     rbx, rax
#         mov     rdi, r14
#         xor     esi, esi
#         mov     edx, 10
#         call    strtol
#         shl     ebx, 4
#         add     ebx, eax
#         mov     rax, qword ptr [rip + agg_map]
#         movsxd  rcx, ebx
#         shl     rcx, 5
#         cmp     byte ptr [rax + rcx], 0
#         je      .LBB1_6
#         mov     rdx, qword ptr [rax + rcx + 8]
#         movsd   xmm1, qword ptr [rax + rcx + 16] # xmm1 = mem[0],zero
#         movsd   xmm0, qword ptr [rax + rcx + 24] # xmm0 = mem[0],zero
#         add     rdx, 1
#         jmp     .LBB1_7
# .LBB1_6:
#         lea     rdx, [rax + rcx]
#         mov     byte ptr [rdx], 1
#         xorpd   xmm0, xmm0
#         movupd  xmmword ptr [rax + rcx + 8], xmm0
#         mov     qword ptr [rax + rcx + 24], 0
#         mov     edx, 1
#         xorpd   xmm0, xmm0
#         xorpd   xmm1, xmm1
# .LBB1_7:
#         movsd   xmm5, qword ptr [rsp + 8] # 8-byte Reload
#         movapd  xmm2, xmm5
#         subsd   xmm2, xmm1
#         cvtsi2sd        xmm3, rdx
#         movapd  xmm4, xmm2
#         divsd   xmm4, xmm3
#         addsd   xmm4, xmm1
#         subsd   xmm5, xmm4
#         mulsd   xmm5, xmm2
#         addsd   xmm5, xmm0
#         mov     qword ptr [rax + rcx + 8], rdx
#         movsd   qword ptr [rax + rcx + 16], xmm4
#         movsd   qword ptr [rax + rcx + 24], xmm5
# .LBB1_8:
#         xor     eax, eax
#         add     rsp, 16
#         pop     rbx
#         pop     r14
#         pop     r15
#         ret
# .LCPI2_0:
#         .quad   0                       # double 0
# ```

# %% [markdown]
# ## Specialized version, i.e. saving the aggregate but checking for fallback code
#
# ```
# define dso_local i64 @process_cells(i8* nocapture readnone, i8** nocapture readonly, i64* nocapture readnone) local_unnamed_addr #3 !dbg !1357 {
#   call void @llvm.dbg.value(metadata i8* %0, metadata !1362, metadata !DIExpression()), !dbg !1377
#   call void @llvm.dbg.value(metadata i8** %1, metadata !1363, metadata !DIExpression()), !dbg !1377
#   call void @llvm.dbg.value(metadata i64* %2, metadata !1364, metadata !DIExpression()), !dbg !1377
#   %4 = getelementptr inbounds i8*, i8** %1, i64 3, !dbg !1378
#   %5 = load i8*, i8** %4, align 8, !dbg !1378, !tbaa !1354
#   call void @llvm.dbg.value(metadata i8* %5, metadata !1365, metadata !DIExpression()), !dbg !1377
#   %6 = getelementptr inbounds i8*, i8** %1, i64 2, !dbg !1379
#   %7 = load i8*, i8** %6, align 8, !dbg !1379, !tbaa !1354
#   call void @llvm.dbg.value(metadata i8* %7, metadata !1366, metadata !DIExpression()), !dbg !1377
#   call void @llvm.dbg.value(metadata i8* undef, metadata !1367, metadata !DIExpression()), !dbg !1377
#   %8 = getelementptr inbounds i8*, i8** %1, i64 20, !dbg !1380
#   %9 = load i8*, i8** %8, align 8, !dbg !1380, !tbaa !1354
#   call void @llvm.dbg.value(metadata i8* %9, metadata !1368, metadata !DIExpression()), !dbg !1377
#   %10 = tail call i32 @strcmp(i8* %9, i8* getelementptr inbounds ([6 x i8], [6 x i8]* @.str, i64 0, i64 0)) #13, !dbg !1381
#   %11 = icmp eq i32 %10, 0, !dbg !1382
#   br i1 %11, label %12, label %30, !dbg !1383
#
# 12:                                               ; preds = %3
#   %13 = getelementptr inbounds i8*, i8** %1, i64 57, !dbg !1384
#   %14 = load i8*, i8** %13, align 8, !dbg !1384, !tbaa !1354
#   call void @llvm.dbg.value(metadata i8* %14, metadata !1367, metadata !DIExpression()), !dbg !1377
#   %15 = load i8, i8* %14, align 1, !dbg !1385
#   %16 = icmp eq i8 %15, 0, !dbg !1387
#   br i1 %16, label %17, label %30, !dbg !1388
#
# 17:                                               ; preds = %12
#   call void @llvm.dbg.value(metadata i8* %5, metadata !587, metadata !DIExpression()) #12, !dbg !1389
#   %18 = tail call i64 @strtol(i8* nocapture nonnull %5, i8** null, i32 10) #12, !dbg !1391
#   %19 = trunc i64 %18 to i32, !dbg !1391
#   call void @llvm.dbg.value(metadata i32 %19, metadata !1372, metadata !DIExpression()), !dbg !1392
#   call void @llvm.dbg.value(metadata i8* %7, metadata !587, metadata !DIExpression()) #12, !dbg !1393
#   %20 = tail call i64 @strtol(i8* nocapture nonnull %7, i8** null, i32 10) #12, !dbg !1395
#   %21 = trunc i64 %20 to i32, !dbg !1395
#   call void @llvm.dbg.value(metadata i32 %21, metadata !1373, metadata !DIExpression()), !dbg !1392
#   %22 = shl i32 %19, 4, !dbg !1396
#   %23 = add nsw i32 %22, %21, !dbg !1397
#   call void @llvm.dbg.value(metadata i32 %23, metadata !1374, metadata !DIExpression()), !dbg !1392
#   %24 = load %struct.AggregateEntry*, %struct.AggregateEntry** @_ZL7agg_map, align 8, !dbg !1398, !tbaa !1354
#   %25 = sext i32 %23 to i64, !dbg !1398
#   call void @llvm.dbg.value(metadata %struct.AggregateEntry* undef, metadata !1375, metadata !DIExpression()), !dbg !1392
#   %26 = getelementptr inbounds %struct.AggregateEntry, %struct.AggregateEntry* %24, i64 %25, i32 0, !dbg !1399
#   %27 = load i8, i8* %26, align 8, !dbg !1399, !tbaa !1344, !range !1401
#   %28 = icmp eq i8 %27, 0, !dbg !1399
#   br i1 %28, label %29, label %30, !dbg !1402
#
# 29:                                               ; preds = %17
#   store i8 1, i8* %26, align 8, !dbg !1403, !tbaa !1344
#   br label %30, !dbg !1404
#
# 30:                                               ; preds = %12, %3, %29, %17
#   %31 = phi i64 [ 0, %17 ], [ 0, %29 ], [ 0, %3 ], [ 42, %12 ], !dbg !1377
#   ret i64 %31, !dbg !1405
# }
# ```

# %% [markdown]
# x86-assembly:
#
# ```
# process_cells:                          # @process_cells
#         push    r15
#         push    r14
#         push    rbx
#         mov     rbx, rsi
#         mov     r14, qword ptr [rsi + 16]
#         mov     r15, qword ptr [rsi + 24]
#         mov     rdi, qword ptr [rsi + 160]
#         mov     esi, offset .L.str
#         call    strcmp
#         test    eax, eax
#         je      .LBB1_1
# .LBB1_4:
#         xor     ebx, ebx
#         jmp     .LBB1_5
# .LBB1_1:
#         mov     rax, qword ptr [rbx + 456]
#         mov     ebx, 42
#         cmp     byte ptr [rax], 0
#         jne     .LBB1_5
#         xor     ebx, ebx
#         mov     rdi, r15
#         xor     esi, esi
#         mov     edx, 10
#         call    strtol
#         mov     r15, rax
#         mov     rdi, r14
#         xor     esi, esi
#         mov     edx, 10
#         call    strtol
#         shl     r15d, 4
#         add     r15d, eax
#         mov     rax, qword ptr [rip + agg_map]
#         movsxd  rcx, r15d
#         shl     rcx, 5
#         cmp     byte ptr [rax + rcx], 0
#         je      .LBB1_3
# .LBB1_5:
#         mov     rax, rbx
#         pop     rbx
#         pop     r14
#         pop     r15
#         ret
# .LBB1_3:
#         add     rax, rcx
#         mov     byte ptr [rax], 1
#         jmp     .LBB1_4
# .LCPI2_0:
#         .quad   0                       # double 0
# ```
