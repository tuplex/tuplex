# %%
# !mkdir -p data/github

# %%
# !aws s3 cp --recursive s3://tuplex-leonhard/experiments/github/hyper/ data/github/hyper/
# Out:
# download: s3://tuplex-leonhard/experiments/github/hyper/part8.csv.csv to data/github/hyper/part8.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part0.csv.csv to data/github/hyper/part0.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part4.csv.csv to data/github/hyper/part4.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part5.csv.csv to data/github/hyper/part5.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part6.csv.csv to data/github/hyper/part6.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part10.csv.csv to data/github/hyper/part10.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part7.csv.csv to data/github/hyper/part7.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part9.csv.csv to data/github/hyper/part9.csv.csv
# download: s3://tuplex-leonhard/experiments/github/hyper/part2.csv.csv to data/github/hyper/part2.csv.csv
# ...

# %%
# !aws s3 cp --recursive s3://tuplex-leonhard/experiments/github/general/ data/github/general/
# Out:
# download: s3://tuplex-leonhard/experiments/github/general/part8.csv.csv to data/github/general/part8.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part4.csv.csv to data/github/general/part4.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part10.csv.csv to data/github/general/part10.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part5.csv.csv to data/github/general/part5.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part6.csv.csv to data/github/general/part6.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part7.csv.csv to data/github/general/part7.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part9.csv.csv to data/github/general/part9.csv.csv
# download: s3://tuplex-leonhard/experiments/github/general/part0.csv.csv to data/github/general/part0.csv.csv
# ...

# %%
# !ls data/github/hyper/ data/github/general
# Out:
# data/github/general:
# part0.csv.csv  part2.csv.csv  part5.csv.csv  part8.csv.csv
# part1.csv.csv  part3.csv.csv  part6.csv.csv  part9.csv.csv
# part10.csv.csv part4.csv.csv  part7.csv.csv
#
# data/github/hyper/:
# part0.csv.csv  part2.csv.csv  part5.csv.csv  part8.csv.csv
# part1.csv.csv  part3.csv.csv  part6.csv.csv  part9.csv.csv
# part10.csv.csv part4.csv.csv  part7.csv.csv

# %%
import pandas as pd
import glob
import os

# %%
hyper_path = 'data/github/hyper/'
general_path = 'data/github/general/'

# %%
df = pd.DataFrame()
for path in glob.glob(os.path.join(hyper_path, "*.csv")):
    print(path)
    df = pd.concat((df, pd.read_csv(path)))
# Out:
# data/github/hyper/part10.csv.csv
# data/github/hyper/part2.csv.csv
# data/github/hyper/part3.csv.csv
# data/github/hyper/part1.csv.csv
# data/github/hyper/part8.csv.csv
# data/github/hyper/part9.csv.csv
# data/github/hyper/part0.csv.csv
# data/github/hyper/part5.csv.csv
# data/github/hyper/part4.csv.csv
# data/github/hyper/part6.csv.csv
# data/github/hyper/part7.csv.csv

# %%
len(df)
# Out:
# 14835

# %%
df = pd.DataFrame()
for path in glob.glob(os.path.join(general_path, "*.csv")):
    print(path)
    df = pd.concat((df, pd.read_csv(path)))
# Out:
# data/github/general/part10.csv.csv
# data/github/general/part2.csv.csv
# data/github/general/part3.csv.csv
# data/github/general/part1.csv.csv
# data/github/general/part8.csv.csv
# data/github/general/part9.csv.csv
# data/github/general/part0.csv.csv
# data/github/general/part5.csv.csv
# data/github/general/part4.csv.csv
# data/github/general/part6.csv.csv
# data/github/general/part7.csv.csv

# %%
len(df)
# Out:
# 17175

# %%
# outputs for github are NOT correct!

# %%
# !mkdir -p data/flights

# %%
# !aws s3 cp --recursive s3://tuplex-leonhard/experiments/flights/hyper/ data/flights/hyper/
# Out:
# download: s3://tuplex-leonhard/experiments/flights/hyper/part100.csv.csv to data/flights/hyper/part100.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part0.csv.csv to data/flights/hyper/part0.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part1.csv.csv to data/flights/hyper/part1.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part103.csv.csv to data/flights/hyper/part103.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part104.csv.csv to data/flights/hyper/part104.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part10.csv.csv to data/flights/hyper/part10.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part101.csv.csv to data/flights/hyper/part101.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/hyper/part106.csv.csv to data/flights/hyper/part106.csv.csv
# ...

# %%
# !aws s3 cp --recursive s3://tuplex-leonhard/experiments/flights/general/ data/flights/general/
# Out:
# download: s3://tuplex-leonhard/experiments/flights/general/part10.csv.csv to data/flights/general/part10.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part101.csv.csv to data/flights/general/part101.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part0.csv.csv to data/flights/general/part0.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part103.csv.csv to data/flights/general/part103.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part1.csv.csv to data/flights/general/part1.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part100.csv.csv to data/flights/general/part100.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part107.csv.csv to data/flights/general/part107.csv.csv
# download: s3://tuplex-leonhard/experiments/flights/general/part106.csv.csv to data/flights/general/part106.csv.csv
# ...
