# %%
# some rows apparently seem to have 8 fields.
# why is general-case not picking this up?

# %%
import json

# %%
path = '/home/leonhard/projects/tuplex-public/tuplex/test/resources/2011-11-26-13.json.gz'

# %%
import gzip

# %%
with gzip.open(path, 'r') as fp:
    data = fp.read().decode()

# %%
lines = data.split('\n')

# %%
lines[-1]
# Out:
# ''

# %%
json.loads(lines[-1])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 json.loads(lines[-1])
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
rows = [json.loads(L) for L in lines if len(L) > 0]

# %%
[len(list(row.keys())) for row in rows]
# Out:
# [7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  8,
#  8,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  7,
#  8,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  8,
#  7,
#  7,
#  8,
#  7,
#  7,
#  ...]

# %%
[sorted(list(row.keys())) for row in rows][:15]
# Out:
# [['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'org', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type'],
#  ['actor', 'created_at', 'id', 'payload', 'public', 'repo', 'type']]

# %%
S = set()
for x in [sorted(list(row['payload'].keys())) for row in rows]:
    for y in x:
        S.add(y)
S
# Out:
# {'action',
#  'comment',
#  'commits',
#  'description',
#  'download',
#  'forkee',
#  'gist',
#  'head',
#  'issue',
#  'master_branch',
#  'member',
#  'number',
#  'pages',
#  'pull_request',
#  'push_id',
#  'ref',
#  'ref_type',
#  'size',
#  'target'}

# %%
rows[0]
# Out:
# {'type': 'PushEvent',
#  'repo': {'url': 'https://api.github.dev/repos/roofimon/GWTBook',
#   'id': 2769611,
#   'name': 'roofimon/GWTBook'},
#  'created_at': '2011-11-26T13:00:00Z',
#  'payload': {'commits': [{'author': {'name': 'roofimon',
#      'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#     'sha': 'a8f7e9bd3e24180347e4971712965ad6aaac95cf',
#     'message': 'test',
#     'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/a8f7e9bd3e24180347e4971712965ad6aaac95cf'},
#    {'author': {'name': 'roofimon',
#      'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#     'sha': '93fe080f01c6649a87d48cdd698f0b9fbe7a71cc',
#     'message': "Merge branch 'master' of github.com:roofimon/GWTBook",
#     'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/93fe080f01c6649a87d48cdd698f0b9fbe7a71cc'},
#    {'author': {'name': 'roofimon',
#      'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#     'sha': '017d240800362843c47bedbaf909cd950a894a3c',
#     'message': 'Finish RPC Trial',
#     'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/017d240800362843c47bedbaf909cd950a894a3c'}],
#   'ref': 'refs/heads/master',
#   'head': '017d240800362843c47bedbaf909cd950a894a3c',
#   'size': 3,
#   'push_id': 51473559},
#  'actor': {'gravatar_id': '340088a06970533e7d981e4120a932a0',
#   'url': 'https://api.github.dev/users/roofimon',
#   'avatar_url': 'https://secure.gravatar.com/avatar/340088a06970533e7d981e4120a932a0?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#   'id': 29492,
#   'login': 'roofimon'},
#  'public': True,
#  'id': '1501206832'}

# %%
print(json.dumps(json.loads(lines[2]), indent=2))
# Out:
# {
#   "type": "PushEvent",
#   "repo": {
#     "url": "https://api.github.dev/repos/maestro/NICU_DB",
#     "id": 2854542,
#     "name": "maestro/NICU_DB"
#   },
#   "created_at": "2011-11-26T13:00:01Z",
#   "payload": {
#     "commits": [
#       {
#         "author": {
#           "name": "math",
#           "email": "ff1a531624cef0a76d4d96e463da60a4bffe0180@gmail.com"
#         },
#         "sha": "5194ed61efc45b443d4b9033707b838b6aad90a5",
#         "message": "\u30ea\u30ec\u30fc\u30b7\u30e7\u30f3\u3092\u5b9a\u7fa9",
#         "url": "https://api.github.com/repos/maestro/NICU_DB/commits/5194ed61efc45b443d4b9033707b838b6aad90a5"
#       }
#     ],
#     "ref": "refs/heads/master",
#     "head": "5194ed61efc45b443d4b9033707b838b6aad90a5",
#     "size": 1,
#     "push_id": 51473560
#   },
#   "actor": {
#     "gravatar_id": "b02572eebc1bd24c4f8218755e784951",
#     "url": "https://api.github.dev/users/maestro",
#     "avatar_url": "https://secure.gravatar.com/avatar/b02572eebc1bd24c4f8218755e784951?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png",
#     "id": 97370,
#     "login": "maestro"
#   },
#   "public": true,
#   "id": "1501206836"
# }

# %%
# 'commits': true
# 'ref': true
# 'head': true
# 'size': true
# 'push_id': true

# %%
sum([len(set(row['payload'].keys()) & {'commits', 'ref', 'head', 'size', 'push_id'}) == 5 for row in rows])
# Out:
# 1102

# %%
# --> basically a quarter.

# %%
# "payload":{
#     "action": (maybe) str,
#     "comment": (maybe) {
#       "body":str,
#       "commit_id": (maybe) str,
#       "created_at":str,
#       "html_url": (maybe) str,
#       "id":i64,
#       "line": (maybe) i64,
#       "path": (maybe) str,
#       "position": (maybe) i64,
#       "updated_at":str,
#       "url":str,
#       "user":{
#         "gravatar_id":str,
#         "id":i64,
#         "url":str,
#         "login":str,
#         "avatar_url":str
#       }
#     },
#     "commits": (maybe) List[Struct[(str,'author'->Struct[(str,'name'->str),(str,'email'->str)]),(str,'sha'->str),(str,'message'->str),(str,'url'->str)]],
#     "description": (maybe) str,
#     "download": (maybe) {
#       "created_at":str,
#       "content_type":str,
#       "name":str,
#       "id":i64,
#       "description":str,
#       "html_url":str,
#       "size":i64,
#       "url":str,
#       "download_count":i64
#     },
#     "forkee": (maybe) {
#       "clone_url":str,
#       "created_at":str,
#       "description":str,
#       "fork":boolean,
#       "forks":i64,
#       "git_url":str,
#       "homepage":str,
#       "html_url":str,
#       "id":i64,
#       "language":str,
#       "master_branch":null,
#       "name":str,
#       "open_issues":i64,
#       "owner":{
#         "gravatar_id":str,
#         "id":i64,
#         "url":str,
#         "login":str,
#         "avatar_url":str
#       },
#       "private":boolean,
#       "public":boolean,
#       "pushed_at":str,
#       "size":i64,
#       "ssh_url":str,
#       "svn_url":str,
#       "updated_at":str,
#       "url":str,
#       "watchers":i64
#     },
#     "gist": (maybe) {
#       "comments":i64,
#       "created_at":str,
#       "description":str,
#       "files":{},
#       "git_pull_url":str,
#       "git_push_url":str,
#       "html_url":str,
#       "id":str,
#       "public":boolean,
#       "updated_at":str,
#       "url":str,
#       "user":null
#     },
#     "head": (maybe) str,
#     "issue": (maybe) {
#       "assignee":null,
#       "body":str,
#       "closed_at":Option[str],
#       "comments":i64,
#       "created_at":str,
#       "html_url":str,
#       "id":i64,
#       "labels":[],
#       "milestone":null,
#       "number":i64,
#       "pull_request":{
#         "patch_url":null,
#         "html_url":null,
#         "diff_url":null
#       },
#       "state":str,
#       "title":str,
#       "updated_at":str,
#       "url":str,
#       "user":{
#         "gravatar_id":str,
#         "id":i64,
#         "url":str,
#         "login":str,
#         "avatar_url":str
#       }
#     },
#     "master_branch": (maybe) str,
#     "number": (maybe) i64,
#     "pull_request": (maybe) {
#       "_links":{
#         "review_comments":{
#           "href":str
#         },
#         "comments":{
#           "href":str
#         },
#         "html":{
#           "href":str
#         },
#         "self":{
#           "href":str
#         }
#       },
#       "additions":i64,
#       "base":{
#         "label":str,
#         "ref":str,
#         "repo":{
#           "clone_url":str,
#           "created_at":str,
#           "description":str,
#           "fork":boolean,
#           "forks":i64,
#           "git_url":str,
#           "homepage":str,
#           "html_url":str,
#           "id":i64,
#           "language":str,
#           "master_branch":null,
#           "name":str,
#           "open_issues":i64,
#           "owner":{
#             "gravatar_id":str,
#             "id":i64,
#             "url":str,
#             "login":str,
#             "avatar_url":str
#           },
#           "private":boolean,
#           "pushed_at":str,
#           "size":i64,
#           "ssh_url":str,
#           "svn_url":str,
#           "updated_at":str,
#           "url":str,
#           "watchers":i64
#         },
#         "sha":str,
#         "user":{
#           "gravatar_id":str,
#           "id":i64,
#           "url":str,
#           "login":str,
#           "avatar_url":str
#         }
#       },
#       "body":str,
#       "changed_files":i64,
#       "closed_at":str,
#       "comments":i64,
#       "commits":i64,
#       "created_at":str,
#       "deletions":i64,
#       "diff_url":str,
#       "head":{
#         "label":str,
#         "ref":str,
#         "repo":{
#           "clone_url":str,
#           "created_at":str,
#           "description":str,
#           "fork":boolean,
#           "forks":i64,
#           "git_url":str,
#           "homepage":str,
#           "html_url":str,
#           "id":i64,
#           "language":str,
#           "master_branch":null,
#           "name":str,
#           "open_issues":i64,
#           "owner":{
#             "gravatar_id":str,
#             "id":i64,
#             "url":str,
#             "login":str,
#             "avatar_url":str
#           },
#           "private":boolean,
#           "pushed_at":str,
#           "size":i64,
#           "ssh_url":str,
#           "svn_url":str,
#           "updated_at":str,
#           "url":str,
#           "watchers":i64
#         },
#         "sha":str,
#         "user":{
#           "gravatar_id":str,
#           "id":i64,
#           "url":str,
#           "login":str,
#           "avatar_url":str
#         }
#       },
#       "html_url":str,
#       "id":i64,
#       "issue_url":str,
#       "mergeable":null,
#       "merged":boolean,
#       "merged_at":str,
#       "merged_by":{
#         "gravatar_id":str,
#         "id":i64,
#         "url":str,
#         "login":str,
#         "avatar_url":str
#       },
#       "number":i64,
#       "patch_url":str,
#       "review_comments":i64,
#       "state":str,
#       "title":str,
#       "updated_at":str,
#       "url":str,
#       "user":{
#         "gravatar_id":str,
#         "id":i64,
#         "url":str,
#         "login":str,
#         "avatar_url":str
#       }
#     },
#     "push_id": (maybe) i64,
#     "ref": (maybe) Option[str],
#     "ref_type": (maybe) str,
#     "size": (maybe) i64,
#     "target": (maybe) {
#       "avatar_url":str,
#       "bio":Option[str],
#       "blog":str,
#       "company":Option[str],
#       "created_at":str,
#       "email":str,
#       "followers":i64,
#       "following":i64,
#       "gravatar_id":str,
#       "hireable":boolean,
#       "html_url":str,
#       "id":i64,
#       "location":str,
#       "login":str,
#       "name":str,
#       "public_gists":i64,
#       "public_repos":i64,
#       "type":str,
#       "url":str
#     }
#   },

# %%
[x.split('),(')
# Out:
# ["Struct[(str,'action'=>str",
#  "str,'comment'=>Struct[(str,'body'->str",
#  "str,'commit_id'=>str",
#  "str,'created_at'->str",
#  "str,'html_url'=>str",
#  "str,'id'->i64",
#  "str,'line'=>i64",
#  "str,'path'=>str",
#  "str,'position'=>i64",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'user'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)])]",
#  "str,'commits'=>List[Struct[(str,'author'->Struct[(str,'name'->str",
#  "str,'email'->str)]",
#  "str,'sha'->str",
#  "str,'message'->str",
#  "str,'url'->str)]]",
#  "str,'description'=>str",
#  "str,'download'=>Struct[(str,'created_at'->str",
#  "str,'content_type'->str",
#  "str,'name'->str",
#  "str,'id'->i64",
#  "str,'description'->str",
#  "str,'html_url'->str",
#  "str,'size'->i64",
#  "str,'url'->str",
#  "str,'download_count'->i64)]",
#  "str,'forkee'=>Struct[(str,'clone_url'->str",
#  "str,'created_at'->str",
#  "str,'description'->str",
#  "str,'fork'->boolean",
#  "str,'forks'->i64",
#  "str,'git_url'->str",
#  "str,'homepage'->str",
#  "str,'html_url'->str",
#  "str,'id'->i64",
#  "str,'language'->str",
#  "str,'master_branch'->null",
#  "str,'name'->str",
#  "str,'open_issues'->i64",
#  "str,'owner'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)]",
#  "str,'private'->boolean",
#  "str,'public'->boolean",
#  "str,'pushed_at'->str",
#  "str,'size'->i64",
#  "str,'ssh_url'->str",
#  "str,'svn_url'->str",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'watchers'->i64)]",
#  "str,'gist'=>Struct[(str,'comments'->i64",
#  "str,'created_at'->str",
#  "str,'description'->str",
#  "str,'files'->{}",
#  "str,'git_pull_url'->str",
#  "str,'git_push_url'->str",
#  "str,'html_url'->str",
#  "str,'id'->str",
#  "str,'public'->boolean",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'user'->null)]",
#  "str,'head'=>str",
#  "str,'issue'=>Struct[(str,'assignee'->null",
#  "str,'body'->str",
#  "str,'closed_at'->Option[str]",
#  "str,'comments'->i64",
#  "str,'created_at'->str",
#  "str,'html_url'->str",
#  "str,'id'->i64",
#  "str,'labels'->[]",
#  "str,'milestone'->null",
#  "str,'number'->i64",
#  "str,'pull_request'->Struct[(str,'patch_url'->null",
#  "str,'html_url'->null",
#  "str,'diff_url'->null)]",
#  "str,'state'->str",
#  "str,'title'->str",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'user'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)])]",
#  "str,'master_branch'=>str",
#  "str,'number'=>i64",
#  "str,'pull_request'=>Struct[(str,'_links'->Struct[(str,'review_comments'->Struct[(str,'href'->str)]",
#  "str,'comments'->Struct[(str,'href'->str)]",
#  "str,'html'->Struct[(str,'href'->str)]",
#  "str,'self'->Struct[(str,'href'->str)])]",
#  "str,'additions'->i64",
#  "str,'base'->Struct[(str,'label'->str",
#  "str,'ref'->str",
#  "str,'repo'->Struct[(str,'clone_url'->str",
#  "str,'created_at'->str",
#  "str,'description'->str",
#  "str,'fork'->boolean",
#  "str,'forks'->i64",
#  "str,'git_url'->str",
#  "str,'homepage'->str",
#  "str,'html_url'->str",
#  "str,'id'->i64",
#  "str,'language'->str",
#  "str,'master_branch'->null",
#  "str,'name'->str",
#  "str,'open_issues'->i64",
#  "str,'owner'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)]",
#  "str,'private'->boolean",
#  "str,'pushed_at'->str",
#  "str,'size'->i64",
#  "str,'ssh_url'->str",
#  "str,'svn_url'->str",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'watchers'->i64)]",
#  "str,'sha'->str",
#  "str,'user'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)])]",
#  "str,'body'->str",
#  "str,'changed_files'->i64",
#  "str,'closed_at'->str",
#  "str,'comments'->i64",
#  "str,'commits'->i64",
#  "str,'created_at'->str",
#  "str,'deletions'->i64",
#  "str,'diff_url'->str",
#  "str,'head'->Struct[(str,'label'->str",
#  "str,'ref'->str",
#  "str,'repo'->Struct[(str,'clone_url'->str",
#  "str,'created_at'->str",
#  "str,'description'->str",
#  "str,'fork'->boolean",
#  "str,'forks'->i64",
#  "str,'git_url'->str",
#  "str,'homepage'->str",
#  "str,'html_url'->str",
#  "str,'id'->i64",
#  "str,'language'->str",
#  "str,'master_branch'->null",
#  "str,'name'->str",
#  "str,'open_issues'->i64",
#  "str,'owner'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)]",
#  "str,'private'->boolean",
#  "str,'pushed_at'->str",
#  "str,'size'->i64",
#  "str,'ssh_url'->str",
#  "str,'svn_url'->str",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'watchers'->i64)]",
#  "str,'sha'->str",
#  "str,'user'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)])]",
#  "str,'html_url'->str",
#  "str,'id'->i64",
#  "str,'issue_url'->str",
#  "str,'mergeable'->null",
#  "str,'merged'->boolean",
#  "str,'merged_at'->str",
#  "str,'merged_by'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)]",
#  "str,'number'->i64",
#  "str,'patch_url'->str",
#  "str,'review_comments'->i64",
#  "str,'state'->str",
#  "str,'title'->str",
#  "str,'updated_at'->str",
#  "str,'url'->str",
#  "str,'user'->Struct[(str,'gravatar_id'->str",
#  "str,'id'->i64",
#  "str,'url'->str",
#  "str,'login'->str",
#  "str,'avatar_url'->str)])]",
#  "str,'push_id'=>i64",
#  "str,'ref'=>Option[str]",
#  "str,'ref_type'=>str",
#  "str,'size'=>i64",
#  "str,'target'=>Struct[(str,'avatar_url'->str",
#  "str,'bio'->Option[str]",
#  "str,'blog'->str",
#  "str,'company'->Option[str]",
#  "str,'created_at'->str",
#  "str,'email'->str",
#  "str,'followers'->i64",
#  "str,'following'->i64",
#  "str,'gravatar_id'->str",
#  "str,'hireable'->boolean",
#  "str,'html_url'->str",
#  "str,'id'->i64",
#  "str,'location'->str",
#  "str,'login'->str",
#  "str,'name'->str",
#  "str,'public_gists'->i64",
#  "str,'public_repos'->i64",
#  "str,'type'->str",
#  "str,'url'->str)])]"]

# %%
[row['payload'].get('created_at') for row in rows]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
#decoded key=avatar_url as str [i8*] : [0x7f5a88369010] https://secure.gravatar.com/avatar/340088a06970533e7d981e4120a932a0?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png
decoded key=gravatar_id as str [i8*] : [0x7f5a883690a0] 340088a06970533e7d981e4120a932a0
decoded key=id as i64 [i64] : 29492
decoded key=login as str [i8*] : [0x7f5a883690d0] roofimon
decoded key=url as str [i8*] : [0x7f5a883690e0] https://api.github.dev/users/roofimon
decoded key=created_at as str [i8*] : [0x7f5a88369110] 2011-11-26T13:00:00Z
decoded key=id as str [i8*] : [0x7f5a88369130] 1501206832

# %%
help(json.dumps)
# Out:
# Help on function dumps in module json:
#
# dumps(obj, *, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)
#     Serialize ``obj`` to a JSON formatted ``str``.
#
#     If ``skipkeys`` is true then ``dict`` keys that are not basic types
#     (``str``, ``int``, ``float``, ``bool``, ``None``) will be skipped
#     instead of raising a ``TypeError``.
#
#     If ``ensure_ascii`` is false, then the return value can contain non-ASCII
#     characters if they appear in strings contained in ``obj``. Otherwise, all
#     such characters are escaped in JSON strings.
#
#     If ``check_circular`` is false, then the circular reference check
#     for container types will be skipped and a circular reference will
#     result in an ``RecursionError`` (or worse).
#
#     If ``allow_nan`` is false, then it will be a ``ValueError`` to
#     serialize out of range ``float`` values (``nan``, ``inf``, ``-inf``) in
#     strict compliance of the JSON specification, instead of using the
#     JavaScript equivalents (``NaN``, ``Infinity``, ``-Infinity``).
#
#     If ``indent`` is a non-negative integer, then JSON array elements and
#     object members will be pretty-printed with that indent level. An indent
#     level of 0 will only insert newlines. ``None`` is the most compact
#     representation.
#
#     If specified, ``separators`` should be an ``(item_separator, key_separator)``
#     tuple.  The default is ``(', ', ': ')`` if *indent* is ``None`` and
#     ``(',', ': ')`` otherwise.  To get the most compact JSON representation,
#     you should specify ``(',', ':')`` to eliminate whitespace.
#
#     ``default(obj)`` is a function that should return a serializable version
#     of obj or raise TypeError. The default simply raises TypeError.
#
#     If *sort_keys* is true (default: ``False``), then the output of
#     dictionaries will be sorted by key.
#
#     To use a custom ``JSONEncoder`` subclass (e.g. one that overrides the
#     ``.default()`` method to serialize additional types), specify it with
#     the ``cls`` kwarg; otherwise ``JSONEncoder`` is used.

# %%
rows[:5]
# Out:
# [{'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/roofimon/GWTBook',
#    'id': 2769611,
#    'name': 'roofimon/GWTBook'},
#   'created_at': '2011-11-26T13:00:00Z',
#   'payload': {'commits': [{'author': {'name': 'roofimon',
#       'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#      'sha': 'a8f7e9bd3e24180347e4971712965ad6aaac95cf',
#      'message': 'test',
#      'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/a8f7e9bd3e24180347e4971712965ad6aaac95cf'},
#     {'author': {'name': 'roofimon',
#       'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#      'sha': '93fe080f01c6649a87d48cdd698f0b9fbe7a71cc',
#      'message': "Merge branch 'master' of github.com:roofimon/GWTBook",
#      'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/93fe080f01c6649a87d48cdd698f0b9fbe7a71cc'},
#     {'author': {'name': 'roofimon',
#       'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#      'sha': '017d240800362843c47bedbaf909cd950a894a3c',
#      'message': 'Finish RPC Trial',
#      'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/017d240800362843c47bedbaf909cd950a894a3c'}],
#    'ref': 'refs/heads/master',
#    'head': '017d240800362843c47bedbaf909cd950a894a3c',
#    'size': 3,
#    'push_id': 51473559},
#   'actor': {'gravatar_id': '340088a06970533e7d981e4120a932a0',
#    'url': 'https://api.github.dev/users/roofimon',
#    'avatar_url': 'https://secure.gravatar.com/avatar/340088a06970533e7d981e4120a932a0?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 29492,
#    'login': 'roofimon'},
#   'public': True,
#   'id': '1501206832'},
#  {'type': 'MemberEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tanzilaafzal/php_project',
#    'id': 2850585,
#    'name': 'tanzilaafzal/php_project'},
#   'created_at': '2011-11-26T13:00:00Z',
#   'payload': {'action': 'added',
#    'member': {'gravatar_id': 'e00d24e8d5245035d756aa0c943dc9ef',
#     'id': 1220629,
#     'url': 'https://api.github.com/users/salehamuqaddas',
#     'login': 'salehamuqaddas',
#     'avatar_url': 'https://secure.gravatar.com/avatar/e00d24e8d5245035d756aa0c943dc9ef?d=https://a248.e.akamai.net/assets.github.com%2Fimages%2Fgravatars%2Fgravatar-140.png'}},
#   'actor': {'gravatar_id': '5a69d25d69cc406c146595322d3cda10',
#    'url': 'https://api.github.dev/users/tanzilaafzal',
#    'avatar_url': 'https://secure.gravatar.com/avatar/5a69d25d69cc406c146595322d3cda10?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1218406,
#    'login': 'tanzilaafzal'},
#   'public': True,
#   'id': '1501206833'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/maestro/NICU_DB',
#    'id': 2854542,
#    'name': 'maestro/NICU_DB'},
#   'created_at': '2011-11-26T13:00:01Z',
#   'payload': {'commits': [{'author': {'name': 'math',
#       'email': 'ff1a531624cef0a76d4d96e463da60a4bffe0180@gmail.com'},
#      'sha': '5194ed61efc45b443d4b9033707b838b6aad90a5',
#      'message': 'リレーションを定義',
#      'url': 'https://api.github.com/repos/maestro/NICU_DB/commits/5194ed61efc45b443d4b9033707b838b6aad90a5'}],
#    'ref': 'refs/heads/master',
#    'head': '5194ed61efc45b443d4b9033707b838b6aad90a5',
#    'size': 1,
#    'push_id': 51473560},
#   'actor': {'gravatar_id': 'b02572eebc1bd24c4f8218755e784951',
#    'url': 'https://api.github.dev/users/maestro',
#    'avatar_url': 'https://secure.gravatar.com/avatar/b02572eebc1bd24c4f8218755e784951?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 97370,
#    'login': 'maestro'},
#   'public': True,
#   'id': '1501206836'},
#  {'type': 'CreateEvent',
#   'repo': {'url': 'https://api.github.dev/repos/maruchinu/tuwien-funkprog-tests-2011ws',
#    'id': 2855542,
#    'name': 'maruchinu/tuwien-funkprog-tests-2011ws'},
#   'created_at': '2011-11-26T13:00:05Z',
#   'payload': {'master_branch': 'master',
#    'ref': None,
#    'description': 'TU Wien, Funktionale Programmierung 2001WS, Testfallsammlung',
#    'ref_type': 'repository'},
#   'actor': {'gravatar_id': '1606e10441d70486e9ff8b83fa6a3788',
#    'url': 'https://api.github.dev/users/maruchinu',
#    'avatar_url': 'https://secure.gravatar.com/avatar/1606e10441d70486e9ff8b83fa6a3788?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 278346,
#    'login': 'maruchinu'},
#   'public': True,
#   'id': '1501206842'},
#  {'type': 'WatchEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tonymillion/Reachability',
#    'id': 2759563,
#    'name': 'tonymillion/Reachability'},
#   'created_at': '2011-11-26T13:00:08Z',
#   'payload': {'action': 'started'},
#   'actor': {'gravatar_id': '5a571ddc5f6c3fe0da7d5bef6fe90379',
#    'url': 'https://api.github.dev/users/entangledstate',
#    'avatar_url': 'https://secure.gravatar.com/avatar/5a571ddc5f6c3fe0da7d5bef6fe90379?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 217,
#    'login': 'entangledstate'},
#   'public': True,
#   'id': '1501206847'}]

# %%
# !pwd
# Out:
# /home/leonhard/projects/tuplex-public/experimental/notebooks

# %%
# !ls ../../tuplex/test/resources/
# Out:
# 2011-02-12-0.json.gz
# 2011-11-26-13.json.gz
# 311_subset.micro.csv
# 311_subset.small.csv
# aggbykey_large_test.csv
# bad_ips_all.txt
# extract_price_data.csv
# flight_ifwithnulls.sample.csv
# flightinf.csv
# flight_mini.csv
# flight_sample_mini_2015_2.csv
# flights_bad.csv
# flights_on_time_performance_2019_01.sample.csv
# flights_on_time_performance_2019_01.sample.tworows.csv
# GlobalAirportDatabase_sample.txt
# gtrace-jobevents-sample.csv
# joins
# L_CARRIER_HISTORY_sample.csv
# ndjson
# optional_str_test.csv
# pipelines
# pyref
# quotednulls.csv
# spark-csv
# spectrum-csv
# test.csv
# tpch
# unique_test_res.txt
# unique_test.txt
# weblogs.small.csv
# zillow_data.csv
# zillow_dirty.csv
# zillow_dirty_sample.csv
# zillow_dirty_sample_mini.csv

# %%
sample = []
for r in rows[:20]:
    
    sample.append({k : v for k, v in r.items()})
    del sample[-1]['payload']
sample
# Out:
# [{'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/roofimon/GWTBook',
#    'id': 2769611,
#    'name': 'roofimon/GWTBook'},
#   'created_at': '2011-11-26T13:00:00Z',
#   'actor': {'gravatar_id': '340088a06970533e7d981e4120a932a0',
#    'url': 'https://api.github.dev/users/roofimon',
#    'avatar_url': 'https://secure.gravatar.com/avatar/340088a06970533e7d981e4120a932a0?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 29492,
#    'login': 'roofimon'},
#   'public': True,
#   'id': '1501206832'},
#  {'type': 'MemberEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tanzilaafzal/php_project',
#    'id': 2850585,
#    'name': 'tanzilaafzal/php_project'},
#   'created_at': '2011-11-26T13:00:00Z',
#   'actor': {'gravatar_id': '5a69d25d69cc406c146595322d3cda10',
#    'url': 'https://api.github.dev/users/tanzilaafzal',
#    'avatar_url': 'https://secure.gravatar.com/avatar/5a69d25d69cc406c146595322d3cda10?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1218406,
#    'login': 'tanzilaafzal'},
#   'public': True,
#   'id': '1501206833'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/maestro/NICU_DB',
#    'id': 2854542,
#    'name': 'maestro/NICU_DB'},
#   'created_at': '2011-11-26T13:00:01Z',
#   'actor': {'gravatar_id': 'b02572eebc1bd24c4f8218755e784951',
#    'url': 'https://api.github.dev/users/maestro',
#    'avatar_url': 'https://secure.gravatar.com/avatar/b02572eebc1bd24c4f8218755e784951?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 97370,
#    'login': 'maestro'},
#   'public': True,
#   'id': '1501206836'},
#  {'type': 'CreateEvent',
#   'repo': {'url': 'https://api.github.dev/repos/maruchinu/tuwien-funkprog-tests-2011ws',
#    'id': 2855542,
#    'name': 'maruchinu/tuwien-funkprog-tests-2011ws'},
#   'created_at': '2011-11-26T13:00:05Z',
#   'actor': {'gravatar_id': '1606e10441d70486e9ff8b83fa6a3788',
#    'url': 'https://api.github.dev/users/maruchinu',
#    'avatar_url': 'https://secure.gravatar.com/avatar/1606e10441d70486e9ff8b83fa6a3788?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 278346,
#    'login': 'maruchinu'},
#   'public': True,
#   'id': '1501206842'},
#  {'type': 'WatchEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tonymillion/Reachability',
#    'id': 2759563,
#    'name': 'tonymillion/Reachability'},
#   'created_at': '2011-11-26T13:00:08Z',
#   'actor': {'gravatar_id': '5a571ddc5f6c3fe0da7d5bef6fe90379',
#    'url': 'https://api.github.dev/users/entangledstate',
#    'avatar_url': 'https://secure.gravatar.com/avatar/5a571ddc5f6c3fe0da7d5bef6fe90379?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 217,
#    'login': 'entangledstate'},
#   'public': True,
#   'id': '1501206847'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/rathrio/sample_app',
#    'id': 2846265,
#    'name': 'rathrio/sample_app'},
#   'created_at': '2011-11-26T13:00:09Z',
#   'actor': {'gravatar_id': 'd8759fea685fc18baf193567c4e8aff5',
#    'url': 'https://api.github.dev/users/rathrio',
#    'avatar_url': 'https://secure.gravatar.com/avatar/d8759fea685fc18baf193567c4e8aff5?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 868879,
#    'login': 'rathrio'},
#   'public': True,
#   'id': '1501206848'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/uzonyib/Keno',
#    'id': 2711054,
#    'name': 'uzonyib/Keno'},
#   'created_at': '2011-11-26T13:00:09Z',
#   'actor': {'gravatar_id': 'cd938e6cf67fbf9552e95ada298fe1dd',
#    'url': 'https://api.github.dev/users/uzonyib',
#    'avatar_url': 'https://secure.gravatar.com/avatar/cd938e6cf67fbf9552e95ada298fe1dd?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 324266,
#    'login': 'uzonyib'},
#   'public': True,
#   'id': '1501206849'},
#  {'type': 'GollumEvent',
#   'repo': {'url': 'https://api.github.dev/repos/alexshen/stateless',
#    'id': 2848105,
#    'name': 'alexshen/stateless'},
#   'created_at': '2011-11-26T13:00:10Z',
#   'actor': {'gravatar_id': 'c9532a7dcd7bfe29245011722ee693cd',
#    'url': 'https://api.github.dev/users/alexshen',
#    'avatar_url': 'https://secure.gravatar.com/avatar/c9532a7dcd7bfe29245011722ee693cd?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 874771,
#    'login': 'alexshen'},
#   'public': True,
#   'id': '1501206853'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tonuonu/TYROS',
#    'id': 1761316,
#    'name': 'tonuonu/TYROS'},
#   'created_at': '2011-11-26T13:00:11Z',
#   'actor': {'gravatar_id': 'b1ae202137780b6bd20c9cbef9bb16c5',
#    'url': 'https://api.github.dev/users/tonuonu',
#    'avatar_url': 'https://secure.gravatar.com/avatar/b1ae202137780b6bd20c9cbef9bb16c5?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 776233,
#    'login': 'tonuonu'},
#   'public': True,
#   'id': '1501206854'},
#  {'org': {'gravatar_id': '3e41d29e64b7945249532765a1a02ffd',
#    'url': 'https://api.github.dev/orgs/wojodesign',
#    'avatar_url': 'https://secure.gravatar.com/avatar/3e41d29e64b7945249532765a1a02ffd?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-org-420.png',
#    'id': 55094,
#    'login': 'wojodesign'},
#   'type': 'IssuesEvent',
#   'repo': {'url': 'https://api.github.dev/repos/wojodesign/simplecart-js',
#    'id': 130473,
#    'name': 'wojodesign/simplecart-js'},
#   'created_at': '2011-11-26T13:00:12Z',
#   'actor': {'gravatar_id': '0339957b86af44885d3ef0726c49f914',
#    'url': 'https://api.github.dev/users/ndisain',
#    'avatar_url': 'https://secure.gravatar.com/avatar/0339957b86af44885d3ef0726c49f914?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1221633,
#    'login': 'ndisain'},
#   'public': True,
#   'id': '1501206856'},
#  {'type': 'CreateEvent',
#   'repo': {'url': 'https://api.github.dev/repos/zakobyte/g_test',
#    'id': 2855543,
#    'name': 'zakobyte/g_test'},
#   'created_at': '2011-11-26T13:00:12Z',
#   'actor': {'gravatar_id': '57f087f35a52fc3fe6bf4de640952313',
#    'url': 'https://api.github.dev/users/zakobyte',
#    'avatar_url': 'https://secure.gravatar.com/avatar/57f087f35a52fc3fe6bf4de640952313?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1220510,
#    'login': 'zakobyte'},
#   'public': True,
#   'id': '1501206857'},
#  {'type': 'WatchEvent',
#   'repo': {'url': 'https://api.github.dev/repos/jstorimer/spin',
#    'id': 2663201,
#    'name': 'jstorimer/spin'},
#   'created_at': '2011-11-26T13:00:14Z',
#   'actor': {'gravatar_id': '3f582b2bc3caf0d7074e85cdf2046a0f',
#    'url': 'https://api.github.dev/users/steakknife',
#    'avatar_url': 'https://secure.gravatar.com/avatar/3f582b2bc3caf0d7074e85cdf2046a0f?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 224304,
#    'login': 'steakknife'},
#   'public': True,
#   'id': '1501206859'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/suikay/extention_GL',
#    'id': 2848732,
#    'name': 'suikay/extention_GL'},
#   'created_at': '2011-11-26T13:00:22Z',
#   'actor': {'gravatar_id': 'bf2222f67638f4625f2c945ee4e55dc0',
#    'url': 'https://api.github.dev/users/suikay',
#    'avatar_url': 'https://secure.gravatar.com/avatar/bf2222f67638f4625f2c945ee4e55dc0?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1180231,
#    'login': 'suikay'},
#   'public': True,
#   'id': '1501206863'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/spurious/ironscheme-mirror',
#    'id': 1406793,
#    'name': 'spurious/ironscheme-mirror'},
#   'created_at': '2011-11-26T13:00:23Z',
#   'actor': {'gravatar_id': '43879d0feeead0dcdf6b3fa368714eef',
#    'url': 'https://api.github.dev/users/spurious',
#    'avatar_url': 'https://secure.gravatar.com/avatar/43879d0feeead0dcdf6b3fa368714eef?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 577737,
#    'login': 'spurious'},
#   'public': True,
#   'id': '1501206865'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/agamadurska/AIISE-Coursework-2',
#    'id': 2846381,
#    'name': 'agamadurska/AIISE-Coursework-2'},
#   'created_at': '2011-11-26T13:00:23Z',
#   'actor': {'gravatar_id': '21ad40fe4b0081e83685ab5148ed33b2',
#    'url': 'https://api.github.dev/users/ICGog',
#    'avatar_url': 'https://secure.gravatar.com/avatar/21ad40fe4b0081e83685ab5148ed33b2?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 433340,
#    'login': 'ICGog'},
#   'public': True,
#   'id': '1501206866'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/edavis10/redmine',
#    'id': 21692,
#    'name': 'edavis10/redmine'},
#   'created_at': '2011-11-26T13:00:24Z',
#   'actor': {'gravatar_id': 'ae959c6836366656b895069d75ad09bf',
#    'url': 'https://api.github.dev/users/edavis10',
#    'avatar_url': 'https://secure.gravatar.com/avatar/ae959c6836366656b895069d75ad09bf?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1621,
#    'login': 'edavis10'},
#   'public': True,
#   'id': '1501206868'},
#  {'type': 'WatchEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tmm1/rbtrace',
#    'id': 1349627,
#    'name': 'tmm1/rbtrace'},
#   'created_at': '2011-11-26T13:00:31Z',
#   'actor': {'gravatar_id': 'dec159fdeaac98fb3d4e953f10427b9a',
#    'url': 'https://api.github.dev/users/ainame',
#    'avatar_url': 'https://secure.gravatar.com/avatar/dec159fdeaac98fb3d4e953f10427b9a?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 748949,
#    'login': 'ainame'},
#   'public': True,
#   'id': '1501206872'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/yaroot/dotfiles',
#    'id': 1241239,
#    'name': 'yaroot/dotfiles'},
#   'created_at': '2011-11-26T13:00:32Z',
#   'actor': {'gravatar_id': '401ad6a93ccabe0d8fb1898d18181171',
#    'url': 'https://api.github.dev/users/yaroot',
#    'avatar_url': 'https://secure.gravatar.com/avatar/401ad6a93ccabe0d8fb1898d18181171?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 42634,
#    'login': 'yaroot'},
#   'public': True,
#   'id': '1501206874'},
#  {'org': {'gravatar_id': '1831dd5ae0880d515d7cc9294b220537',
#    'url': 'https://api.github.dev/orgs/rug-compling',
#    'avatar_url': 'https://secure.gravatar.com/avatar/1831dd5ae0880d515d7cc9294b220537?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-org-420.png',
#    'id': 505073,
#    'login': 'rug-compling'},
#   'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/rug-compling/alpinocorpus',
#    'id': 1129396,
#    'name': 'rug-compling/alpinocorpus'},
#   'created_at': '2011-11-26T13:00:34Z',
#   'actor': {'gravatar_id': 'f3b31f3e7c724ac53609410877fdda81',
#    'url': 'https://api.github.dev/users/danieldk',
#    'avatar_url': 'https://secure.gravatar.com/avatar/f3b31f3e7c724ac53609410877fdda81?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 49398,
#    'login': 'danieldk'},
#   'public': True,
#   'id': '1501206875'},
#  {'type': 'WatchEvent',
#   'repo': {'url': 'https://api.github.dev/repos/imathis/octopress',
#    'id': 341626,
#    'name': 'imathis/octopress'},
#   'created_at': '2011-11-26T13:00:36Z',
#   'actor': {'gravatar_id': 'f9e4bc40b0cdc50d03503b262b409510',
#    'url': 'https://api.github.dev/users/viper1092',
#    'avatar_url': 'https://secure.gravatar.com/avatar/f9e4bc40b0cdc50d03503b262b409510?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1096025,
#    'login': 'viper1092'},
#   'public': True,
#   'id': '1501206876'}]

# %%
sample = [rows[0]]

# %%
with open('../../tuplex/test/resources//2011-11-26-13.sample3.json', 'w') as fp:
    fp.writelines([json.dumps(row) + '\n' for row in sample])

# %%
# Intrpduce slowly complexity of payload by adding in some subgroups. The full field is WAY to complex.

# %%
rows[:5]
# Out:
# [{'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/roofimon/GWTBook',
#    'id': 2769611,
#    'name': 'roofimon/GWTBook'},
#   'created_at': '2011-11-26T13:00:00Z',
#   'payload': {'commits': [{'author': {'name': 'roofimon',
#       'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#      'sha': 'a8f7e9bd3e24180347e4971712965ad6aaac95cf',
#      'message': 'test',
#      'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/a8f7e9bd3e24180347e4971712965ad6aaac95cf'},
#     {'author': {'name': 'roofimon',
#       'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#      'sha': '93fe080f01c6649a87d48cdd698f0b9fbe7a71cc',
#      'message': "Merge branch 'master' of github.com:roofimon/GWTBook",
#      'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/93fe080f01c6649a87d48cdd698f0b9fbe7a71cc'},
#     {'author': {'name': 'roofimon',
#       'email': '476ec616bb33cddae3c030e4c8f8e05233728fe9@gmail.com'},
#      'sha': '017d240800362843c47bedbaf909cd950a894a3c',
#      'message': 'Finish RPC Trial',
#      'url': 'https://api.github.com/repos/roofimon/GWTBook/commits/017d240800362843c47bedbaf909cd950a894a3c'}],
#    'ref': 'refs/heads/master',
#    'head': '017d240800362843c47bedbaf909cd950a894a3c',
#    'size': 3,
#    'push_id': 51473559},
#   'actor': {'gravatar_id': '340088a06970533e7d981e4120a932a0',
#    'url': 'https://api.github.dev/users/roofimon',
#    'avatar_url': 'https://secure.gravatar.com/avatar/340088a06970533e7d981e4120a932a0?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 29492,
#    'login': 'roofimon'},
#   'public': True,
#   'id': '1501206832'},
#  {'type': 'MemberEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tanzilaafzal/php_project',
#    'id': 2850585,
#    'name': 'tanzilaafzal/php_project'},
#   'created_at': '2011-11-26T13:00:00Z',
#   'payload': {'action': 'added',
#    'member': {'gravatar_id': 'e00d24e8d5245035d756aa0c943dc9ef',
#     'id': 1220629,
#     'url': 'https://api.github.com/users/salehamuqaddas',
#     'login': 'salehamuqaddas',
#     'avatar_url': 'https://secure.gravatar.com/avatar/e00d24e8d5245035d756aa0c943dc9ef?d=https://a248.e.akamai.net/assets.github.com%2Fimages%2Fgravatars%2Fgravatar-140.png'}},
#   'actor': {'gravatar_id': '5a69d25d69cc406c146595322d3cda10',
#    'url': 'https://api.github.dev/users/tanzilaafzal',
#    'avatar_url': 'https://secure.gravatar.com/avatar/5a69d25d69cc406c146595322d3cda10?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 1218406,
#    'login': 'tanzilaafzal'},
#   'public': True,
#   'id': '1501206833'},
#  {'type': 'PushEvent',
#   'repo': {'url': 'https://api.github.dev/repos/maestro/NICU_DB',
#    'id': 2854542,
#    'name': 'maestro/NICU_DB'},
#   'created_at': '2011-11-26T13:00:01Z',
#   'payload': {'commits': [{'author': {'name': 'math',
#       'email': 'ff1a531624cef0a76d4d96e463da60a4bffe0180@gmail.com'},
#      'sha': '5194ed61efc45b443d4b9033707b838b6aad90a5',
#      'message': 'リレーションを定義',
#      'url': 'https://api.github.com/repos/maestro/NICU_DB/commits/5194ed61efc45b443d4b9033707b838b6aad90a5'}],
#    'ref': 'refs/heads/master',
#    'head': '5194ed61efc45b443d4b9033707b838b6aad90a5',
#    'size': 1,
#    'push_id': 51473560},
#   'actor': {'gravatar_id': 'b02572eebc1bd24c4f8218755e784951',
#    'url': 'https://api.github.dev/users/maestro',
#    'avatar_url': 'https://secure.gravatar.com/avatar/b02572eebc1bd24c4f8218755e784951?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 97370,
#    'login': 'maestro'},
#   'public': True,
#   'id': '1501206836'},
#  {'type': 'CreateEvent',
#   'repo': {'url': 'https://api.github.dev/repos/maruchinu/tuwien-funkprog-tests-2011ws',
#    'id': 2855542,
#    'name': 'maruchinu/tuwien-funkprog-tests-2011ws'},
#   'created_at': '2011-11-26T13:00:05Z',
#   'payload': {'master_branch': 'master',
#    'ref': None,
#    'description': 'TU Wien, Funktionale Programmierung 2001WS, Testfallsammlung',
#    'ref_type': 'repository'},
#   'actor': {'gravatar_id': '1606e10441d70486e9ff8b83fa6a3788',
#    'url': 'https://api.github.dev/users/maruchinu',
#    'avatar_url': 'https://secure.gravatar.com/avatar/1606e10441d70486e9ff8b83fa6a3788?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 278346,
#    'login': 'maruchinu'},
#   'public': True,
#   'id': '1501206842'},
#  {'type': 'WatchEvent',
#   'repo': {'url': 'https://api.github.dev/repos/tonymillion/Reachability',
#    'id': 2759563,
#    'name': 'tonymillion/Reachability'},
#   'created_at': '2011-11-26T13:00:08Z',
#   'payload': {'action': 'started'},
#   'actor': {'gravatar_id': '5a571ddc5f6c3fe0da7d5bef6fe90379',
#    'url': 'https://api.github.dev/users/entangledstate',
#    'avatar_url': 'https://secure.gravatar.com/avatar/5a571ddc5f6c3fe0da7d5bef6fe90379?d=http://github.dev%2Fimages%2Fgravatars%2Fgravatar-user-420.png',
#    'id': 217,
#    'login': 'entangledstate'},
#   'public': True,
#   'id': '1501206847'}]
