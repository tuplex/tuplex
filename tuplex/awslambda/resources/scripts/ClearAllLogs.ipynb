# %%
import boto3
import argparse

import time

client = boto3.client("logs")

log_group_name = '/aws/lambda/tuplex-lambda-runner'

limit = 50

# get log streams
log_streams_response = client.describe_log_streams(logGroupName=log_group_name, limit=limit)

while 'nextToken' in log_streams_response:
    tstart = time.time()
    print('Starting to delete logs...')
    nextToken = log_streams_response['nextToken']
    n_logs = len(log_streams_response['logStreams'])
    
    responses = [client.delete_log_stream(
        logGroupName=log_group_name, logStreamName=stream["logStreamName"]
    ) for stream in log_streams_response['logStreams']]
    
    print('Deleted {} logs in {:.2f}s'.format(len(responses), time.time() - tstart))
    
    log_streams_response = client.describe_log_streams(logGroupName=log_group_name, nextToken=nextToken, limit=limit)
# Out:
# Starting to delete logs...
# Deleted 50 logs in 5.75s
# Starting to delete logs...
# Deleted 50 logs in 13.32s
# Starting to delete logs...
# Deleted 50 logs in 8.58s
# Starting to delete logs...
# Deleted 50 logs in 7.61s
# Starting to delete logs...
# Deleted 50 logs in 6.75s
# Starting to delete logs...
# Deleted 50 logs in 6.55s
# Starting to delete logs...
# Deleted 50 logs in 9.49s
# Starting to delete logs...
# Deleted 50 logs in 8.32s
# Starting to delete logs...
# Deleted 50 logs in 5.61s
# Starting to delete logs...
# Deleted 50 logs in 13.85s
# Starting to delete logs...
# Deleted 50 logs in 6.95s
# Starting to delete logs...
# Deleted 50 logs in 7.02s
# Starting to delete logs...
# Deleted 50 logs in 6.39s
# Starting to delete logs...
# Deleted 50 logs in 6.88s
# Starting to delete logs...
# Deleted 50 logs in 10.86s
# Starting to delete logs...
# Deleted 50 logs in 7.35s
# Starting to delete logs...
# Deleted 50 logs in 8.21s
# Starting to delete logs...
# Deleted 50 logs in 11.09s
# Starting to delete logs...
# Deleted 50 logs in 10.73s
# Starting to delete logs...
# Deleted 50 logs in 10.51s
# Starting to delete logs...
# Deleted 50 logs in 5.91s
# Starting to delete logs...
# Deleted 50 logs in 7.59s
# Starting to delete logs...
# Deleted 50 logs in 11.48s
# Starting to delete logs...
# Deleted 50 logs in 7.47s
# Starting to delete logs...
# Deleted 50 logs in 12.88s
# Starting to delete logs...
# Deleted 50 logs in 10.97s
# Starting to delete logs...
# Deleted 50 logs in 7.48s
# Starting to delete logs...

# %%
log_streams_response.keys()
# Out:
# dict_keys(['logStreams', 'nextToken', 'ResponseMetadata'])

# %%
log_streams_response['ResponseMetadata']
# Out:
# {'RequestId': '491a5de7-2b82-4642-b92a-be550f28d89e',
#  'HTTPStatusCode': 200,
#  'HTTPHeaders': {'x-amzn-requestid': '491a5de7-2b82-4642-b92a-be550f28d89e',
#   'content-type': 'application/x-amz-json-1.1',
#   'content-length': '23272',
#   'date': 'Tue, 18 Jan 2022 04:38:00 GMT'},
#  'RetryAttempts': 0}

# %%
from tqdm import tqdm

# %%
for stream in tqdm(log_streams_response['logStreams']):
    client.delete_log_stream(
        logGroupName=log_group_name, logStreamName=stream["logStreamName"]
    )
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  7.30it/s]

# %%
log_streams_response['logStreams']
# Out:
# [{'logStreamName': '2021/11/25/[$LATEST]34f1de5f807b473387c5a100cf9e4522',
#   'creationTime': 1637876871542,
#   'firstEventTimestamp': 1637876863346,
#   'lastEventTimestamp': 1637876980460,
#   'lastIngestionTime': 1637876989273,
#   'uploadSequenceToken': '49621947480691696787442876049760767537652068577009729794',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST

#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]6f34fe36c4b943d3b2924059aab93530',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]70122091dbe749c5a549e92a8700ce87',
#   'creationTime': 1637876864957,
#   'firstEventTimestamp': 1637876863331,
#   'lastEventTimestamp': 1637876986054,
#   'lastIngestionTime': 1637876986224,
#   'uploadSequenceToken': '49603090611163025865513705576073985581005768030943183970',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]70122091dbe749c5a549e92a8700ce87',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]72c265a6c85d47b6b2e8e6c54b0712a5',
#   'creationTime': 1637876868371,
#   'firstEventTimestamp': 1637876862937,
#   'lastEventTimestamp': 1637876986369,
#   'lastIngestionTime': 1637876986703,
#   'uploadSequenceToken': '49621947480691696787442876047990900137736251259081457922',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]72c265a6c85d47b6b2e8e6c54b0712a5',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]795a9d7c8dda4ae886e5234027c638a6',
#   'creationTime': 1637876872900,
#   'firstEventTimestamp': 1637876864623,
#   'lastEventTimestamp': 1637876989412,
#   'lastIngestionTime': 1637876998337,
#   'uploadSequenceToken': '49613032146289850081940769210324681636951796048474406962',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]795a9d7c8dda4ae886e5234027c638a6',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]79b7f3d897fb4564bd2647bd022a600d',
#   'creationTime': 1637876870623,
#   'firstEventTimestamp': 1637876861569,
#   'lastEventTimestamp': 1637876990020,
#   'lastIngestionTime': 1637876998874,
#   'uploadSequenceToken': '49622069952370192981886557922978783566131013622729539778',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]79b7f3d897fb4564bd2647bd022a600d',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]7e4f480fe4184b2f8cc92fe99ecd8279',
#   'creationTime': 1637876866840,
#   'firstEventTimestamp': 1637876864910,
#   'lastEventTimestamp': 1637876983539,
#   'lastIngestionTime': 1637876983904,
#   'uploadSequenceToken': '49622813899699431154240379818960328155391387788004819266',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]7e4f480fe4184b2f8cc92fe99ecd8279',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]7ea7d12e570b4af0bb2bcbbbe384870b',
#   'creationTime': 1637876863391,
#   'firstEventTimestamp': 1637876863068,
#   'lastEventTimestamp': 1637876987193,
#   'lastIngestionTime': 1637876996109,
#   'uploadSequenceToken': '49621947480691696787442876054470742530870664253981851906',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]7ea7d12e570b4af0bb2bcbbbe384870b',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]812d0ce694a040ffb97b6ac3073f1f0c',
#   'creationTime': 1637876871177,
#   'firstEventTimestamp': 1637876863502,
#   'lastEventTimestamp': 1637876989127,
#   'lastIngestionTime': 1637876998015,
#   'uploadSequenceToken': '49621947480691696787442876055833201929576351540034142466',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]812d0ce694a040ffb97b6ac3073f1f0c',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]81816e4c1b79411cb5b66606bc1f6a83',
#   'creationTime': 1637876873090,
#   'firstEventTimestamp': 1637876864888,
#   'lastEventTimestamp': 1637876980488,
#   'lastIngestionTime': 1637876989407,
#   'uploadSequenceToken': '49621947480691696787442876049858690529040853540160930050',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]81816e4c1b79411cb5b66606bc1f6a83',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]88af510443da476b91102097be89ad49',
#   'creationTime': 1637876863061,
#   'firstEventTimestamp': 1637876862743,
#   'lastEventTimestamp': 1637876989137,
#   'lastIngestionTime': 1637876998049,
#   'uploadSequenceToken': '49622813899699431154240379830140474135187479357760209218',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]88af510443da476b91102097be89ad49',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]88df665c7d3a4e979f0bb4c25126ec0b',
#   'creationTime': 1637876870094,
#   'firstEventTimestamp': 1637876863170,
#   'lastEventTimestamp': 1637876989639,
#   'lastIngestionTime': 1637876998659,
#   'uploadSequenceToken': '49621947480691696787442876056247863485704169415677837570',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]88df665c7d3a4e979f0bb4c25126ec0b',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]8ab7fe8193c84d20a0644d359d01db51',
#   'creationTime': 1637876868121,
#   'firstEventTimestamp': 1637876861352,
#   'lastEventTimestamp': 1637876981819,
#   'lastIngestionTime': 1637876990715,
#   'uploadSequenceToken': '49603090611163025865513705576718343042860365724658959458',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]8ab7fe8193c84d20a0644d359d01db51',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]8cf5ea26ed6f46c2ad42699242eee89f',
#   'creationTime': 1637876866307,
#   'firstEventTimestamp': 1637876863210,
#   'lastEventTimestamp': 1637876984675,
#   'lastIngestionTime': 1637876984952,
#   'uploadSequenceToken': '49603090611163025865513705575880557449867427294270719074',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]8cf5ea26ed6f46c2ad42699242eee89f',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]93c1f52c44944939b1437f4331822acd',
#   'creationTime': 1637876864427,
#   'firstEventTimestamp': 1637876862660,
#   'lastEventTimestamp': 1637876979487,
#   'lastIngestionTime': 1637876988414,
#   'uploadSequenceToken': '49622069952370192981886557921208916166215195823764930754',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]93c1f52c44944939b1437f4331822acd',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]9628c9c7cf724038892a48384cbe23ff',
#   'creationTime': 1637876866484,
#   'firstEventTimestamp': 1637876863497,
#   'lastEventTimestamp': 1637876987028,
#   'lastIngestionTime': 1637876995947,
#   'uploadSequenceToken': '49622069952370192981886557922483123980089015386222100674',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]9628c9c7cf724038892a48384cbe23ff',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]966820138fff476e86b63b10a4454356',
#   'creationTime': 1637876862831,
#   'firstEventTimestamp': 1637876861469,
#   'lastEventTimestamp': 1637876982077,
#   'lastIngestionTime': 1637876982872,
#   'uploadSequenceToken': '49621947480691696787442876045516228984985105132299485442',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]966820138fff476e86b63b10a4454356',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]9915497e46654be2a3210e529f8c099a',
#   'creationTime': 1637876866286,
#   'firstEventTimestamp': 1637876863632,
#   'lastEventTimestamp': 1637876989540,
#   'lastIngestionTime': 1637876998411,
#   'uploadSequenceToken': '49621947480691696787442876056093120980793496812595970306',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]9915497e46654be2a3210e529f8c099a',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]996c522003cf4c3393cda2f76df44da3',
#   'creationTime': 1637876871979,
#   'firstEventTimestamp': 1637876864912,
#   'lastEventTimestamp': 1637876985395,
#   'lastIngestionTime': 1637876994253,
#   'uploadSequenceToken': '49611660156520935046357651092116445233456246771981222114',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]996c522003cf4c3393cda2f76df44da3',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]9bc07233ee3c4e49b2823ad92d5e98c1',
#   'creationTime': 1637876870259,
#   'firstEventTimestamp': 1637876861194,
#   'lastEventTimestamp': 1637876981598,
#   'lastIngestionTime': 1637876990524,
#   'uploadSequenceToken': '49603090611163025865513705576683284194091541409873003618',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]9bc07233ee3c4e49b2823ad92d5e98c1',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]9c91557bd7cb4ce9a869a950e39d4dbe',
#   'creationTime': 1637877126353,
#   'firstEventTimestamp': 1637877122526,
#   'lastEventTimestamp': 1637877122657,
#   'lastIngestionTime': 1637877126360,
#   'uploadSequenceToken': '49622813899699431154240379933631777849117433283750134082',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]9c91557bd7cb4ce9a869a950e39d4dbe',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]a3abacd6600a40978602035cd2fdb1d3',
#   'creationTime': 1637876871985,
#   'firstEventTimestamp': 1637876869052,
#   'lastEventTimestamp': 1637876984676,
#   'lastIngestionTime': 1637876993573,
#   'uploadSequenceToken': '49613032146289850081940769207840339077643732750855831602',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]a3abacd6600a40978602035cd2fdb1d3',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]aa68f60b73ae479d8fd4b709496cfc41',
#   'creationTime': 1637876875907,
#   'firstEventTimestamp': 1637876866847,
#   'lastEventTimestamp': 1637876983880,
#   'lastIngestionTime': 1637876992740,
#   'uploadSequenceToken': '49611660156520935046357651091856526182239101361980440802',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]aa68f60b73ae479d8fd4b709496cfc41',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]acfd318e06704556b3028e6cd50ebe8e',
#   'creationTime': 1637876873417,
#   'firstEventTimestamp': 1637876867678,
#   'lastEventTimestamp': 1637876987440,
#   'lastIngestionTime': 1637876996326,
#   'uploadSequenceToken': '49613032146289850081940769209288632209542058639592783922',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]acfd318e06704556b3028e6cd50ebe8e',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]ae36f985f93c42cf9df6294a9d70e15e',
#   'creationTime': 1637876864359,
#   'firstEventTimestamp': 1637876861741,
#   'lastEventTimestamp': 1637876988515,
#   'lastIngestionTime': 1637876997445,
#   'uploadSequenceToken': '49621676356349044304400983980068255383549340117626782402',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]ae36f985f93c42cf9df6294a9d70e15e',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]ae851df44d7946cf9925a009e3556494',
#   'creationTime': 1637877572601,
#   'firstEventTimestamp': 1637877569358,
#   'lastEventTimestamp': 1637877569493,
#   'lastIngestionTime': 1637877572607,
#   'uploadSequenceToken': '49613032146289850081940769499806804846953249962266198066',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]ae851df44d7946cf9925a009e3556494',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]af6c51b3367e4b52a805f7399dde199d',
#   'creationTime': 1637876863883,
#   'firstEventTimestamp': 1637876861339,
#   'lastEventTimestamp': 1637876982317,
#   'lastIngestionTime': 1637876991209,
#   'uploadSequenceToken': '49621947480691696787442876051109928752341994873420775682',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]af6c51b3367e4b52a805f7399dde199d',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]b2c0bff4a68b4c33888403b9a2be9080',
#   'creationTime': 1637876870276,
#   'firstEventTimestamp': 1637876863559,
#   'lastEventTimestamp': 1637876980430,
#   'lastIngestionTime': 1637876980789,
#   'uploadSequenceToken': '49611660156520935046357651089667161522917007101953835234',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]b2c0bff4a68b4c33888403b9a2be9080',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]b3ab98cf22304f81bf0a50e42dc36103',
#   'creationTime': 1637876862811,
#   'firstEventTimestamp': 1637876861940,
#   'lastEventTimestamp': 1637876988785,
#   'lastIngestionTime': 1637876988898,
#   'uploadSequenceToken': '49622069952370192981886557921286287418670532090946126018',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]b3ab98cf22304f81bf0a50e42dc36103',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]b75924cf1e674b45885c3356569818e3',
#   'creationTime': 1637876863070,
#   'firstEventTimestamp': 1637876861539,
#   'lastEventTimestamp': 1637876981912,
#   'lastIngestionTime': 1637876990931,
#   'uploadSequenceToken': '49621947480691696787442876050916500621203654205467787522',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]b75924cf1e674b45885c3356569818e3',
#   'storedBytes': 0},
#  {'logStreamName': '2021/11/25/[$LATEST]b82d69f041ec45edaecd6e5d518cef7b',
#   'creationTime': 1637876869587,
#   'firstEventTimestamp': 1637876862999,
#   'lastEventTimestamp': 1637876986871,
#   'lastIngestionTime': 1637876995798,
#   'uploadSequenceToken': '49621874046723937762340406182251016139331912886088892978',
#   'arn': 'arn:aws:logs:us-east-1:587583095482:log-group:/aws/lambda/tuplex-lambda-runner:log-stream:2021/11/25/[$LATEST]b82d69f041ec45edaecd6e5d518cef7b',
#   'storedBytes': 0}]
